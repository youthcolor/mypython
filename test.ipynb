# %% [markdown]
# # 第一个jupyter notebook测试

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(20)
y = x**2

plt.plot(x, y)

# %%
# *
# *基础感知：线性拟合数据
# *20180815
 
import numpy as np
#原始数据
X=[ 1 ,2  ,3 ,4 ,5 ,6]
Y=[ 2.6 ,3.4 ,4.7 ,5.5 ,6.47 ,7.8]
 
#用一次多项式拟合，相当于线性拟合
z1 = np.polyfit(X, Y, 1)
p1 = np.poly1d(z1)
print (z1)  #[ 1.          1.49333333]
print (p1)  # 1 x + 1.493
# Out:
# [1.02885714 1.47733333]
#
# 1.029 x + 1.477

# %%
#作图显示
import matplotlib.pyplot as plt
import numpy as np
 
x = np.arange(1,7)
print (x)
y = z1[0] * x + z1[1]
print(y)
plt.figure()
plt.scatter(X, Y)
plt.plot(x, y)
plt.show()
# Out:
# [1 2 3 4 5 6]
# [2.50619048 3.53504762 4.56390476 5.5927619  6.62161905 7.65047619]
